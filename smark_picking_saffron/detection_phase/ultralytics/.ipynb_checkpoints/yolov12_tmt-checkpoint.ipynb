# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("yolo12n.pt")
# Train the model on the COCO8 dataset for 100 epochs
train_results = model.train(
#         cfg='yolo12n',
        task= 'detect' ,
        mode= 'train' ,
        data= '/home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/data.yaml',
        epochs=20 ,
        imgsz=224 ,
        freeze= 0,
        plots=True)
# Evaluate the model's performance on the validation set
metrics = model.val()
# Out:
# New https://pypi.org/project/ultralytics/8.3.146 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.135 🚀 Python-3.10.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7973MiB)
# ...

# %%
# !whereis ultralytics
# Out:
# ultralytics: /home/philipslinux/anaconda3/bin/ultralytics

# %%
#Validation have GT
from ultralytics import YOLO
model = YOLO('./runs/detect/train/weights/best.pt')
model.val(
    data='/home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/data.yaml',
    split='val',
    save=True ,
    save_txt=True)
# Out:
# Ultralytics 8.3.135 🚀 Python-3.10.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7973MiB)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2466.6±1035.1 MB/s, size: 60.9 KB)
# val: Scanning /home/philipslinux/Documents/trieu_others/dataset_saffron/flow_sti
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        227       1158      0.708      0.618      0.656      0.328
#                 Flower        227        667      0.737      0.708      0.748      0.427
#                 stigma        157        491      0.679      0.527      0.563      0.229
# Speed: 0.2ms preprocess, 2.2ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/val5
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
#Test have GT
from ultralytics import YOLO
model = YOLO('./runs/detect/train/weights/best.pt')
model.val(
    data='/home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/data.yaml',
    split='test',
    save=True ,
    save_txt=True)
# Out:
# Ultralytics 8.3.135 🚀 Python-3.10.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7973MiB)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3202.7±1071.5 MB/s, size: 59.5 KB)
# val: Scanning /home/philipslinux/Documents/trieu_others/dataset_saffron/flow_sti
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        118        531      0.735      0.647      0.699      0.327
#                 Flower        118        267      0.837      0.764      0.836      0.473
#                 stigma         98        264      0.633       0.53      0.562      0.181
# Speed: 0.2ms preprocess, 3.3ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/val3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
#Test dont have GT
from ultralytics import YOLO
model = YOLO('./runs/detect/train/weights/best.pt')
model.predict(
    source='/home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/test/images',  # a folder, file, URL, or glob
    save=True,                     # save images with boxes
    save_txt=True,                 # save predictions in YOLO .txt format
    conf=0.25                      # optional confidence threshold
)
# Out:
# image 1/118 /home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/test/images/1000_F_501114635_AKD1VN4b5absEafh3qWi6waRrcfkQ2CY_jpg.rf.07c6b0d2bf5b2e4b53bc136dc6254dfe.jpg: 224x224 1 Flower, 3 stigmas, 6.1ms
# image 2/118 /home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/test/images/10_jpg.rf.7cd926a1f9f00b2ce26c0a4a50377469.jpg: 224x224 2 Flowers, 6.5ms
# image 3/118 /home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/test/images/19_jpg.rf.5a636b48ceab7918d1a58932dd969a42.jpg: 224x224 2 Flowers, 2 stigmas, 6.7ms
# image 4/118 /home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/test/images/1caf29808967ab5438fb27983fa8f347_jpg.rf.4b2fc31b66051df4bfed0d410b591fed.jpg: 224x224 3 Flowers, 4 stigmas, 6.8ms
# image 5/118 /home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/test/images/1fbe294e8a11cd79a45a6cc80043ffa4_jpg.rf.2eaadd1462566e91db5262b3bcaf2dc2.jpg: 224x224 2 Flowers, 4 stigmas, 6.4ms
# ...

# %%
from ultralytics import YOLO
model = YOLO('./runs/detect/train/weights/best.pt')
# Run validation on the validation split
metrics = model.val(
    data='/home/philipslinux/Documents/trieu_others/dataset_saffron/flow_stigmas/data.yaml',
    split='val'  # explicitly mention split if needed
)
# Out:
# Ultralytics 8.3.135 🚀 Python-3.10.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7973MiB)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3379.4±458.5 MB/s, size: 68.8 KB)
# val: Scanning /home/philipslinux/Documents/trieu_others/dataset_saffron/flow_sti
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        118        531      0.735      0.647      0.699      0.327
#                 Flower        118        267      0.837      0.764      0.836      0.473
#                 stigma         98        264      0.633       0.53      0.562      0.181
# Speed: 0.4ms preprocess, 2.9ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/val4

# %%
model.info(verbose=True)
summary = model.model.model  # internal layers
for layer in summary:
    print(layer)
# Out:
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# Conv(
#   (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (act): SiLU(inplace=True)
# )
# Conv(
#   (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (act): SiLU(inplace=True)
# )
# C3k2(
#   (cv1): Conv(
#     (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#     (act): SiLU(inplace=True)
#   )
#   (cv2): Conv(
#     (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1))
#     (act): SiLU(inplace=True)
#   )
#   (m): ModuleList(
#     (0): Bottleneck(
#       (cv1): Conv(
#         (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#   )
# )
# Conv(
# ...
